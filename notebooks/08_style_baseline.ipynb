# %% [markdown]
# ## module 2 — stylize, baseline (placeholder)
#
# turn a plant photo into artwork. baseline: plain neural style transfer — vgg-19
# content/style features, gram-matrix style loss, optimize a blended image (gatys; the
# assignment-3 technique, which has no course notebook — this fills that gap). one content
# photo, one style image, zero plant knowledge: the floor that 09 has to beat.
#
# **status: placeholder — not built yet.** planned scope below; owner tbd.

# %%
# todo: content photo (hf dataset sample) + style image (botanical plate / watercolor) loaders

# %%
# todo: gatys loop — vgg-19 features, content loss + gram-matrix style loss, lbfgs/adam
# tune content/style weights; ~5-10 species examples

# %%
# todo: results grid + metrics — ssim to content (structure kept?), clip similarity to
# style text (style landed?); both carry over to 09 for a fair comparison
