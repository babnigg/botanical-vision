# %% [markdown]
# ## module 2b — stylize, retrieval-enhanced (placeholder)
#
# more than style transfer: use what the classifier knows. the baseline (08) sees pixels;
# this pipeline sees the *species*:
#
# ```
# photo ─► classify (shared resnet-50 checkpoint) ─► retrieve same-species exemplars +
# style references from an embedding index (resnet penultimate 2048-d, the image-search
# pattern) ─► generate artwork conditioned on the retrieved set (ip-adapter / sd img2img)
# ```
#
# so a coneflower stays a coneflower — petal count, leaf shape, habit — because generation
# is guided by real conspecific images, not just one photo. compared against 08 on the same
# ssim/clip metrics plus a species-fidelity check (does the classifier still recognize the
# artwork?).
#
# **status: placeholder — not built yet.** planned scope below; owner tbd.

# %%
# todo: embedding index — resnet-50 penultimate features over an hf dataset sample
# (faiss or plain cosine; the image-search app pattern)

# %%
# todo: classify + retrieve — top-1 species -> k nearest conspecific images; retrieval grid

# %%
# todo: generation — ip-adapter (style + subject refs) or sd img2img with retrieved guidance;
# needs ~6gb vram for sd 1.5 — same low-vram path as notebook 12

# %%
# todo: eval vs 08 — ssim to content, clip style similarity, and species-fidelity:
# classifier top-1 on the generated artwork (does it survive stylization?)
